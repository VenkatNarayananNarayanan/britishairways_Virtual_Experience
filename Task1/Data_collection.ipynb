# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
reviews = [] #empty list to collect the reviews
stars = [] # empty list to collect the rating
date =[] # empty list to collect the date of the review 
country = [] # emplty list to collect the country the reviewer is fom

# %%
for i in range(1, 36):
    page = requests.get(f"https://www.airlinequality.com/airline-reviews/british-airways/page/{i}/?sortby=post_date%3ADesc&pagesize=100")
    
    soup = BeautifulSoup(page.content, "html5")
    
    for item in soup.find_all("div", class_="text_content"):
        reviews.append(item.text)
    
    for item in soup.find_all("div", class_ = "rating-10"):
        try:
            stars.append(item.span.text)
        except:
            print(f"Error on page {i}")
            stars.append("None")
            
    #date
    for item in soup.find_all("time"):
        date.append(item.text)
        
    #country
    for item in soup.find_all("h3"):
        country.append(item.span.next_sibling.text.strip(" ()"))
# Out:
# Error on page 30
# Error on page 31
# Error on page 31
# Error on page 33
# Error on page 34

# %%
len(reviews)
# Out:
# 3488

# %%
len(stars)
# Out:
# 3523

# %%
len(date)
# Out:
# 3488

# %%
len(country)
# Out:
# 3488

# %%
stars = stars[:3488]

# %%
len(stars)
# Out:
# 3488

# %%
df = pd.DataFrame({"reviews":reviews,"stars" : stars,"date": date,"country":country})

# %%
df
# Out:
#                                                 reviews  \
# 0     ✅ Trip Verified | A short BA euro trip and thi...
# 1     Not Verified |  We are flying Business class f...
# 2     ✅ Trip Verified |  I am in Australia and on Fr...
# 3     ✅ Trip Verified |  At 7.54 am on the day of tr...
# 4     ✅ Trip Verified |  Would happily fly them agai...
# ...                                                 ...
# 3483  LHR-JFK-LAX-LHR. Check in was ok apart from be...
# 3484  LHR to HAM. Purser addresses all club passenge...
# 3485  My son who had worked for British Airways urge...
# 3486  London City-New York JFK via Shannon on A318 b...
# 3487  SIN-LHR BA12 B747-436 First Class. Old aircraf...
#
#                               stars               date         country
# 0     \n\t\t\t\t\t\t\t\t\t\t\t\t\t5     9th March 2023  United Kingdom
# 1                                 8     8th March 2023   United States
# 2                                 1     6th March 2023       Australia
# 3                                 1     4th March 2023  United Kingdom
# 4                                 2     2nd March 2023   United States
# ...                             ...                ...             ...
# 3483                              7   29th August 2012  United Kingdom
# 3484                              1   28th August 2012  United Kingdom
# 3485                             10  12th October 2011  United Kingdom
# 3486                              8  11th October 2011   United States
# 3487                              9   9th October 2011  United Kingdom
#
# [3488 rows x 4 columns]

# %%
df.head(20)
# Out:
#                                               reviews  \
# 0   ✅ Trip Verified | A short BA euro trip and thi...
# 1   Not Verified |  We are flying Business class f...
# 2   ✅ Trip Verified |  I am in Australia and on Fr...
# 3   ✅ Trip Verified |  At 7.54 am on the day of tr...
# 4   ✅ Trip Verified |  Would happily fly them agai...
# 5   Not Verified |  Flew premium, only worth the e...
# 6   ✅ Trip Verified |  First our morning flight wa...
# 7   ✅ Trip Verified |  Although it was a bit uncom...
# 8   ✅ Trip Verified |  Boarding was decently organ...
# 9   ✅ Trip Verified | Boarding on time and departu...
# 10  ✅ Trip Verified |  My original flight was canc...
# 11  ✅ Trip Verified |  Delayed just for a change. ...
# 12  ✅ Trip Verified |  Very competent check in sta...
# 13  ✅ Trip Verified |  Check in was so slow, no se...
# 14  ✅ Trip Verified |  My review relates to the ap...
# 15  ✅ Trip Verified | This was my first time flyin...
